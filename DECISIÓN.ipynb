# %% [markdown]
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <title>Variables BMW</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       background-color: #f6f6f6;
#       padding: 40px;
#     }
#     table {
#       width: 100%;
#       border-collapse: collapse;
#       margin-bottom: 40px;
#     }
#     th, td {
#       border: 1px solid #ccc;
#       padding: 10px 12px;
#       text-align: left;
#     }
#     th {
#       background-color: #333;
#       color: white;
#     }
#     .section-header {
#       background-color: #444;
#       color: #fff;
#       font-weight: bold;
#       font-size: 1.1em;
#       padding: 10px;
#     }
#     .target-header {
#       background-color: #000;
#       color: #fff;
#       font-weight: bold;
#       font-size: 1.2em;
#       padding: 10px;
#     }
#     .check { color: green; font-weight: bold; }
#     .cross { color: red; font-weight: bold; }
#     .question { color: orange; font-weight: bold; }
#     .fire { color: #d35400; font-weight: bold; }
#   </style>
# </head>
# <body>
#
#   <table>
#     <tr><td colspan="5" class="section-header">VARIABLES FECHAS</td></tr>
#     <tr><th>Variable</th><th>Tipo</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>fecha_registro</td><td>Fecha</td><td><span class="cross">❌ No</span></td><td>Creamos edad y borramos columna</td><td></td></tr>
#     <tr><td>fecha_venta</td><td>Fecha</td><td><span class="cross">❌ No</span></td><td>Creamos edad y borramos columna</td><td></td></tr>
#     <tr><td colspan="5" class="section-header">COLUMNAS CREADAS</td></tr>
#     <tr><th>Variable</th><th>Tipo</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>edad_coche</td><td>Fecha</td><td><span class="check">✅ Sí</span></td><td>Edad del coche</td><td></td></tr>
#     <tr><td colspan="5" class="section-header">VARIABLES CATEGÓRICAS</td></tr>
#     <tr><th>Variable</th><th>Tipo</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>marca</td><td>Categórica</td><td><span class="cross">❌ No</span></td><td>Eliminamos la variable.</td><td>Solo hay BMW, no aporta valor.</td></tr>
#     <tr><td>modelo</td><td>Categórica</td><td><span class="check">✅ Sí</span></td><td>Eliminamos nulos</td><td></td></tr>
#     <tr><td>tipo_gasolina</td><td>Categórica</td><td><span class="check">✅ Sí</span></td><td>Eliminamos columna, poca variabilidad</td><td></td></tr>
#     <tr><td>color</td><td>Categórica</td><td><span class="question">❓ Dudoso</span></td><td>Imputamos 'Desconocido' y codificamos</td><td>No borrar sin probar impacto en el modelo</td></tr>
#     <tr><td>tipo_coche</td><td>Categórica</td><td><span class="check">✅ Sí</span></td><td>Rellenamos moda (Paso 1), luego borramos otros</td><td>Por correlación con el target, evitamos imputar mucho</td></tr>
#     <tr><td colspan="5" class="section-header">VARIABLES NUMÉRICAS</td></tr>
#     <tr><th>Variable</th><th>Tipo</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>km</td><td>Numérica</td><td><span class="check">✅ Sí</span></td><td>Eliminamos nulos</td><td></td></tr>
#     <tr><td>potencia</td><td>Numérica</td><td><span class="check">✅ Sí</span></td><td>Eliminamos nulos</td><td></td></tr>
#     <tr><td colspan="5" class="section-header">COLUMNAS CREADAS</td></tr>
#     <tr><th>Variable</th><th>Tipo</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>cantidad_extras</td><td>Numérica</td><td><span class="check">✅ Sí</span></td><td>Cantidad de extras del coche</td><td></td></tr>
#     <tr><td>km_por_año</td><td>Numérica</td><td><span class="check">✅ Sí</span></td><td>Km por año</td><td></td></tr>
#     <tr><td colspan="5" class="section-header">VARIABLES BOOLEANAS</td></tr>
#     <tr><th>Variable</th><th>Tipo</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>volante_regulable</td><td>Booleana</td><td><span class="check">✅ Sí</span></td><td>Imputamos nulos (modelo y tipo_coche)</td><td></td></tr>
#     <tr><td>aire_acondicionado</td><td>Booleana</td><td><span class="check">✅ Sí</span></td><td>Imputamos nulos (modelo y tipo_coche)</td><td></td></tr>
#     <tr><td>camara_trasera</td><td>Booleana</td><td><span class="check">✅ Sí</span></td><td>Imputamos nulos (modelo y tipo_coche)</td><td></td></tr>
#     <tr><td>asientos_traseros_plegables</td><td>Booleana</td><td><span class="cross">❌ No</span></td><td>Eliminamos columna</td><td></td></tr>
#     <tr><td>elevalunas_electrico</td><td>Booleana</td><td><span class="check">✅ Sí</span></td><td>Imputamos nulos (modelo y tipo_coche)</td><td></td></tr>
#     <tr><td>bluetooth</td><td>Booleana</td><td><span class="check">✅ Sí</span></td><td>Imputamos nulos</td><td></td></tr>
#     <tr><td>gps</td><td>Booleana</td><td><span class="cross">❌ No</span></td><td>Eliminamos columna</td><td></td></tr>
#     <tr><td>alerta_lim_velocidad</td><td>Booleana</td><td><span class="check">✅ Sí</span></td><td>Borramos nulos</td><td></td></tr>
#     <tr><td colspan="5" class="target-header">VARIABLE TARGET</td></tr>
#     <tr><th>Variable</th><th>Tipo</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>precio</td><td>Numérica</td><td><span class="fire">🔥 TARGET</span></td><td>No modificar</td><td></td></tr>
#   </table>
#
# </body>
# </html>
