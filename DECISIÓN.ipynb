# %% [markdown]
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <title>Variables BMW</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       background-color: #f6f6f6;
#       padding: 40px;
#     }
#     table {
#       width: 100%;
#       border-collapse: collapse;
#       margin-bottom: 40px;
#     }
#     th, td {
#       border: 1px solid #ccc;
#       padding: 10px 12px;
#       text-align: left;
#     }
#     th {
#       background-color: #333;
#       color: white;
#     }
#     .section-header {
#       background-color: #444;
#       color: #fff;
#       font-weight: bold;
#       font-size: 1.1em;
#       padding: 10px;
#     }
#     .target-header {
#       background-color: #000;
#       color: #fff;
#       font-weight: bold;
#       font-size: 1.2em;
#       padding: 10px;
#     }
#     .check { color: green; font-weight: bold; }
#     .cross { color: red; font-weight: bold; }
#     .question { color: orange; font-weight: bold; }
#     .fire { color: #d35400; font-weight: bold; }
#   </style>
# </head>
# <body>
#
#   <table>
#     <tr><td colspan="4" class="section-header">VARIABLES FECHAS</td></tr>
#     <tr><th>Variable</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>fecha_registro</td><td><span class="cross">❌ No</span></td><td>Creamos edad y borramos columna</td><td></td></tr>
#     <tr><td>fecha_venta</td><td><span class="cross">❌ No</span></td><td>Creamos edad y borramos columna</td><td></td></tr>
#     <tr><td colspan="4" class="section-header">COLUMNAS CREADAS</td></tr>
#     <tr><th>Variable</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>edad_coche</td><td><span class="check">✅ Sí</span></td><td>Distribuimos por rangos e imputamos moda (4 pasos)</td><td></td></tr>
#     <tr><td colspan="4" class="section-header">VARIABLES CATEGÓRICAS</td></tr>
#     <tr><th>Variable</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>marca</td><td><span class="cross">❌ No</span></td><td>Eliminamos la variable.</td><td>Solo hay BMW, no aporta valor.</td></tr>
#     <tr><td>modelo</td><td><span class="check">✅ Sí</span></td><td>Eliminamos nulos</td><td></td></tr>
#     <tr><td>tipo_gasolina</td><td><span class="check">✅ Sí</span></td><td>Eliminamos columna, poca variabilidad</td><td></td></tr>
#     <tr><td>color</td><td><span class="question">❓ Dudoso</span></td><td>Codificamos color binario y aplicamos moda (4 pasos)</td><td>No borrar sin probar impacto en el modelo</td></tr>
#     <tr><td>tipo_coche</td><td><span class="check">✅ Sí</span></td><td>Rellenamos moda (3 Pasos)</td><td></td></tr>
#     <tr><td colspan="4" class="section-header">VARIABLES NUMÉRICAS</td></tr>
#     <tr><th>Variable</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>km</td><td><span class="check">✅ Sí</span></td><td>Eliminamos nulos</td><td></td></tr>
#     <tr><td>potencia</td><td><span class="check">✅ Sí</span></td><td>Eliminamos nulos</td><td></td></tr>
#     <tr><td colspan="4" class="section-header">COLUMNAS CREADAS</td></tr>
#     <tr><th>Variable</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>cantidad_extras</td><td><span class="check">✅ Sí</span></td><td>Cantidad de extras del coche</td><td></td></tr>
#     <tr><td>km_por_año</td><td><span class="check">✅ Sí</span></td><td>Km por año</td><td></td></tr>
#     <tr><td colspan="4" class="section-header">VARIABLES BOOLEANAS</td></tr>
#     <tr><th>Variable</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>volante_regulable</td><td><span class="check">✅ Sí</span></td><td>Imputamos nulos (modelo y tipo_coche)</td><td></td></tr>
#     <tr><td>aire_acondicionado</td><td><span class="check">✅ Sí</span></td><td>Imputamos moda (3 pasos)</td><td></td></tr>
#     <tr><td>camara_trasera</td><td><span class="check">✅ Sí</span></td><td>Imputamos nulos (modelo y tipo_coche)</td><td></td></tr>
#     <tr><td>asientos_traseros_plegables</td><td><span class="cross">❌ No</span></td><td>Eliminamos columna</td><td></td></tr>
#     <tr><td>elevalunas_electrico</td><td><span class="check">✅ Sí</span></td><td>Imputamos nulos (modelo y tipo_coche)</td><td></td></tr>
#     <tr><td>bluetooth</td><td><span class="check">✅ Sí</span></td><td>Imputamos moda (5 pasos)</td><td></td></tr>
#     <tr><td>gps</td><td><span class="cross">❌ No</span></td><td>Eliminamos columna</td><td></td></tr>
#     <tr><td>alerta_lim_velocidad</td><td><span class="check">✅ Sí</span></td><td>Imputamos moda (3 pasos)</td><td></td></tr>
#     <tr><td colspan="4" class="target-header">VARIABLE TARGET</td></tr>
#     <tr><th>Variable</th><th>¿Útil para predecir el precio?</th><th>Tratamiento propuesto</th><th>Observaciones / Comentarios</th></tr>
#     <tr><td>precio</td><td><span class="fire">🔥 TARGET</span></td><td>No modificar</td><td></td></tr>
#   </table>
#
# </body>
# </html>
